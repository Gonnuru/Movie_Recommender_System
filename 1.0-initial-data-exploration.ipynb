# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Import Warnings and Packages

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
import pandas as pd
import numpy as np
import pandas_profiling
import matplotlib.pyplot as plt
import sweetviz as sv
import missingno
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Importing list of directors file
#
# Dataset link: [Kaggle](https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset)

# %%
df = pd.read_csv('DataSets/Movie500/movie_metadata.csv')

# %% [markdown]
# **Getting a report using Pandas-Profiling**

# %%
# %%time

profile = df.profile_report(title='Movie Profiling Report')
profile.to_file(output_file="moviesdirectors.html")

# %% [markdown]
# **Report generation using sweetviz**

# %%
# %%time
# analyzing the dataset
movies_report = sv.analyze(df)

# %%
# display the report
movies_report.show_html('Movies_SweetViz.html')

# %% [markdown]
# **Traditional approcah: exploring head values**

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                    1000  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                   40000  309404152.0         Action|Adventure|Fantasy  ...
# 2                   11000  200074175.0        Action|Adventure|Thriller  ...
# 3                   27000  448130642.0                  Action|Thriller  ...
# 4                     131          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0              33000.0
# 1                  0.0
# 2              85000.0
# 3             164000.0
# 4                  0.0
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#       color       director_name  num_critic_for_reviews  duration  \
# 3469  Color        Jane Campion                    83.0     121.0
# 3470  Color   Steven Soderbergh                   324.0     110.0
# 3471  Color  Jonathan Liebesman                   140.0      96.0
# 3472  Color        Guy Hamilton                   136.0     121.0
# 3473  Color         Jay Russell                    79.0      95.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 3469                    319.0                    11.0         Ian Mune
# 3470                      0.0                 11000.0    Alex Pettyfer
# 3471                    474.0                    82.0   Emma Caulfield
# 3472                     82.0                   189.0  Geoffrey Holder
# 3473                     13.0                   430.0    Frankie Muniz
#
#       actor_1_facebook_likes        gross                     genres  ...  \
# 3469                    1000   40158000.0        Drama|Music|Romance  ...
# 3470                   17000  113709992.0               Comedy|Drama  ...
# 3471                    1000   32131483.0    Horror|Mystery|Thriller  ...
# 3472                     581   35400000.0  Action|Adventure|Thriller  ...
# 3473                    1000   34099640.0         Drama|Family|Sport  ...
#
#      num_user_for_reviews language      country  content_rating      budget  \
# 3469                241.0  English  New Zealand               R   7000000.0
# 3470                281.0  English          USA               R   7000000.0
# 3471                369.0  English          USA           PG-13  11000000.0
# 3472                251.0  English           UK              PG   7000000.0
# 3473                  NaN      NaN          NaN             NaN         NaN
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 3469      1993.0                   18.0        7.6          1.85
# 3470      2012.0                15000.0        6.1          2.35
# 3471      2003.0                  970.0        4.9          2.35
# 3472      1973.0                  547.0        6.8          1.66
# 3473         NaN                    NaN        NaN           NaN
#
#      movie_facebook_likes
# 3469                  0.0
# 3470              54000.0
# 3471               2000.0
# 3472                  0.0
# 3473                  NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Checking null values

# %%
# generate preview of entries with null values
if len(df[df.isnull().any(axis=1)] != 0):
    print("\nPreview of data with null values:\nxxxxxxxxxxxxx")
    display(df[df.isnull().any(axis=1)].head(10))
    missingno.matrix(df)
    plt.show()
# Out:
# Preview of data with null values:
# xxxxxxxxxxxxx
#      color       director_name  num_critic_for_reviews  duration  \
# 4      NaN         Doug Walker                     NaN       NaN
# 55   Color          Peter Sohn                   298.0      93.0
# 84   Color        Roland Joffé                    10.0     109.0
# 98   Color        Hideaki Anno                     1.0     120.0
# 99   Color       Peter Jackson                   645.0     182.0
# 177  Color                 NaN                    21.0      60.0
# 199  Color          Matt Birch                     1.0       NaN
# 204  Color        Hideaki Anno                     1.0     120.0
# 206  Color          Matt Birch                     4.0       NaN
# 242  Color  Frédéric Forestier                    33.0     116.0
#
#      director_facebook_likes  actor_3_facebook_likes           actor_2_name  \
# 4                      131.0                     NaN             Rob Walker
# 55                     113.0                   113.0            Jack McGraw
# 84                     596.0                   283.0          Alice Englert
# 98                      28.0                    12.0      Shin'ya Tsukamoto
# 99                       0.0                   773.0             Adam Brown
# 177                      NaN                   184.0  Philip Michael Thomas
# 199                      0.0                   159.0            Dave Legeno
# 204                     28.0                    12.0      Shin'ya Tsukamoto
# 206                      0.0                  1000.0             Toby Jones
# 242                      0.0                   141.0        Santiago Segura
#
#      actor_1_facebook_likes        gross  \
# 4                       131          NaN
# 55                      275  123070338.0
# 84                      622          NaN
# 98                      544          NaN
# 99                     5000  303001229.0
# 177                     982          NaN
# 199                   10000          NaN
# 204                     544          NaN
# 206                   10000          NaN
# 242                     936          NaN
#
#                                         genres  ... num_user_for_reviews  \
# 4                                  Documentary  ...                  NaN
# 55   Adventure|Animation|Comedy|Family|Fantasy  ...                345.0
# 84             Action|Adventure|Romance|Sci-Fi  ...                 15.0
# 98        Action|Adventure|Drama|Horror|Sci-Fi  ...                 13.0
# 99                           Adventure|Fantasy  ...               1367.0
# 177        Action|Crime|Drama|Mystery|Thriller  ...                 74.0
# 199                             Action|Fantasy  ...                  2.0
# 204       Action|Adventure|Drama|Horror|Sci-Fi  ...                 13.0
# 206                                    Fantasy  ...                  2.0
# 242            Adventure|Comedy|Family|Fantasy  ...                 36.0
#
#      language  country  content_rating       budget  title_year  \
# 4         NaN      NaN             NaN          NaN         NaN
# 55    English      USA              PG          NaN      2015.0
# 84    English  Belgium               R          NaN      2015.0
# 98   Japanese    Japan             NaN          NaN      2016.0
# 99    English      USA           PG-13  180000000.0      2012.0
# 177   English      USA           TV-14    1500000.0         NaN
# 199   English       UK             NaN          NaN      2011.0
# 204  Japanese    Japan             NaN          NaN      2016.0
# 206   English       UK             NaN          NaN      2010.0
# 242    French   France             NaN   78000000.0      2008.0
#
#     actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 4                     12.0        7.1           NaN                  0.0
# 55                   150.0        6.8          2.35              20000.0
# 84                   525.0        4.5           NaN                677.0
# 98                   106.0        8.2          2.35                  0.0
# 99                   972.0        7.9          2.35             166000.0
# 177                  321.0        7.5          1.33                  0.0
# 199                  570.0        7.5           NaN                 40.0
# 204                  106.0        8.2          2.35                  0.0
# 206                 2000.0        6.4           NaN                 25.0
# 242                  276.0        5.1          2.35                291.0
#
# [10 rows x 28 columns]

# %% [markdown]
# **traditional approach**

# %%
df.isnull().sum()
# Out:
# color                          8
# director_name                 65
# num_critic_for_reviews        11
# duration                       4
# director_facebook_likes       65
# actor_3_facebook_likes         6
# actor_2_name                   4
# actor_1_facebook_likes         0
# gross                        297
# genres                         0
# actor_1_name                   0
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                   6
# facenumber_in_poster           5
# plot_keywords                 44
# movie_imdb_link                0
# num_user_for_reviews           9
# language                       5
# country                        5
# content_rating                84
# budget                       227
# title_year                    70
# actor_2_facebook_likes         5
# imdb_score                     1
# aspect_ratio                  78
# movie_facebook_likes           1
# dtype: int64

# %% [markdown]
# ## Extracting required columns
#
# *The goal of my project is to create a recommendation system which also displays the top 10 actors/cast in the movie. Therefore, i'm going to shed the other columns which are not going to contribute towards my goal*

# %%
data = df.loc[:, ['director_name', 'actor_1_name',
                  'actor_2_name', 'actor_3_name', 'genres', 'movie_title']]
data.head(10)
# Out:
#        director_name     actor_1_name       actor_2_name  \
# 0      James Cameron      CCH Pounder   Joel David Moore
# 1     Gore Verbinski      Johnny Depp      Orlando Bloom
# 2         Sam Mendes  Christoph Waltz       Rory Kinnear
# 3  Christopher Nolan        Tom Hardy     Christian Bale
# 4        Doug Walker      Doug Walker         Rob Walker
# 5     Andrew Stanton     Daryl Sabara    Samantha Morton
# 6          Sam Raimi     J.K. Simmons       James Franco
# 7       Nathan Greno     Brad Garrett       Donna Murphy
# 8        Joss Whedon  Chris Hemsworth  Robert Downey Jr.
# 9        David Yates     Alan Rickman   Daniel Radcliffe
#
#            actor_3_name                                             genres  \
# 0             Wes Studi                    Action|Adventure|Fantasy|Sci-Fi
# 1        Jack Davenport                           Action|Adventure|Fantasy
# 2      Stephanie Sigman                          Action|Adventure|Thriller
# 3  Joseph Gordon-Levitt                                    Action|Thriller
# 4                   NaN                                        Documentary
# 5          Polly Walker                            Action|Adventure|Sci-Fi
# 6         Kirsten Dunst                           Action|Adventure|Romance
# 7           M.C. Gainey  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8    Scarlett Johansson                            Action|Adventure|Sci-Fi
# 9          Rupert Grint                   Adventure|Family|Fantasy|Mystery
#
#                                          movie_title
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# 4  Star Wars: Episode VII - The Force Awakens    ...
# 5                                       John Carter
# 6                                      Spider-Man 3
# 7                                           Tangled
# 8                           Avengers: Age of Ultron
# 9            Harry Potter and the Half-Blood Prince

# %%
data['actor_1_name'] = data['actor_1_name'].replace(np.nan, 'unknown')
data['actor_2_name'] = data['actor_2_name'].replace(np.nan, 'unknown')
data['actor_3_name'] = data['actor_3_name'].replace(np.nan, 'unknown')
data['director_name'] = data['director_name'].replace(np.nan, 'unknown')

# %%
data['genres'] = data['genres'].replace('|', ' ')

# %%
data['movie_title'] = data['movie_title'].str.lower()

# %%
data['movie_title'][1]
# Out:
# "pirates of the caribbean: at world's end\xa0"

# %%
data['movie_title'] = data['movie_title'].apply(lambda x: x[:-1])

# %% [markdown]
# ## Exporting as CSV and dependencies list

# %%
data.to_csv('data.csv', index=False)

# %%
# %load_ext watermark

# # python, ipython, packages, and machine characteristics
# %watermark -v -m -p wget,pandas,numpy,geopy,altair,vega,vega_datasets,watermark 

# # date
# print (" ")
# %watermark -u -n -t -z
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-f0fbd6544567> in <module>
# ----> 1 get_ipython().run_line_magic('load_ext', 'watermark')
#       2
#       3 # python, ipython, packages, and machine characteristics
#       4 get_ipython().run_line_magic('watermark', '-v -m -p wget,pandas,numpy,geopy,altair,vega,vega_datasets,watermark ')
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# <decorator-gen-65> in load_ext(self, module_str)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\extension.py in load_ext(self, module_str)
#      31         if not module_str:
#      32             raise UsageError('Missing module name.')
# ---> 33         res = self.shell.extension_manager.load_extension(module_str)
#      34
#      35         if res == 'already loaded':
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\extensions.py in load_extension(self, module_str)
#      78             if module_str not in sys.modules:
#      79                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 80                     mod = import_module(module_str)
#      81                     if mod.__file__.startswith(self.ipython_extension_dir):
#      82                         print(("Loading extensions from {dir} is deprecated. "
#
# C:\ProgramData\Anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'watermark'

# %%
# from pip._internal.operations.freeze import freeze
# for requirement in freeze(local_only=True):
#     print(requirement)
